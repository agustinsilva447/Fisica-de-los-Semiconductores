# %% [markdown]
# <a href="https://colab.research.google.com/github/agustinsilva447/Fisica-de-los-Semiconductores/blob/main/6_FDvsMB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate

# %%
x = np.linspace(0, 5, 1000)
k = 0.00008636243
T = 300
Ef = 2.5

def fd(x):
  return (1) / (1 + np.e**((x - Ef)/(k*T)))

def mb(x):
  return np.e**(Ef/(k*T)) * np.e**(-x/(k*T))

# %%
plt.plot(x,fd(x), label = "Fermi-Dirac")
plt.plot(x,mb(x), label = "Maxwell-Boltzmann")
plt.ylim(0,2)
plt.legend()
plt.show()

# %%
value = 2.5
integral_fd = integrate.quad(fd,value,5)[0]
integral_mb = integrate.quad(mb,value,5)[0]

print("Integral between {} and {} of the Fermi-Dirac distribution = {}".format(value,5,integral_fd))
print("Integral between {} and {} of the Maxwe-Boltz distribution = {}".format(value,5,integral_mb))
print("Ratio = {}".format(integral_fd/integral_mb))
# Out:
# Integral between 2.5 and 5 of the Fermi-Dirac distribution = 0.017958562458241702
# Integral between 2.5 and 5 of the Maxwe-Boltz distribution = 0.025908729000000127
# Ratio = 0.6931471805599424

# %%
r = []
flag = 0
threshold = 0.99
for i in x[0:-1]:
  r.append(integrate.quad(fd,i,5)[0] / integrate.quad(mb,i,5)[0])
  if flag == 0 and r[-1] > threshold:
    flag = 1
    print("Valor mínimo de energía para superar un ratio de {} = {}".format(threshold,i))
# Out:
# Valor mínimo de energía para superar un ratio de 0.99 = 2.6026026026026026

# %%
plt.title("Ratio entre Fermi-Dirac y Maxwell-Boltzmann")
plt.plot(x[0:-1],r)
plt.ylim(0,1)
plt.plot()
# Out:
# []
