# %% [markdown]
# <a href="https://colab.research.google.com/github/agustinsilva447/Fisica-de-los-Semiconductores/blob/main/13_03_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![eq1.png](data:image/png;base64,...)
#
# ![eq2.png](data:image/png;base64,...)
#
# ![eq3.png](data:image/png;base64,...)
#
# ![eq4.png](data:image/png;base64,...)
#
# ![eq5.png](data:image/png;base64,...)
#
# ![eq6.png](data:image/png;base64,...)
#
# ![eq7.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import eigh_tridiagonal

# %%
N = 2000
dy = 1/N
y = np.linspace(0, 1, N+1)

# %%
def mL2V(y):
    return 500*(1+np.sign(y-0.5))
    #return 1000*(y-0.5)**2
    #return 1000*np.exp(-(y-0.7)**2/(2*0.05**2))

# %%
d = 1/dy**2 + mL2V(y)[1:-1]
e = -1/(2*dy**2) * np.ones(len(d)-1)

# %%
w, v = eigh_tridiagonal(d, e)

# %%
plt.figure(figsize=(10,5))
plt.plot(y, mL2V(y))
plt.title('Potential', fontsize=30)
plt.ylabel('$V/V_0$', fontsize=25)
plt.xlabel('$x/L$', fontsize=25)
plt.grid()
plt.savefig('v3p1.png', dpi=200)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(y[1:-1], v.T[0])
plt.plot(y[1:-1], v.T[1])
plt.plot(y[1:-1], v.T[2])
plt.plot(y[1:-1], v.T[3])
plt.title('Eigenstates', fontsize=30)
plt.ylabel('$\psi$', fontsize=25)
plt.xlabel('$x/L$', fontsize=25)
plt.grid()
plt.savefig('v3p2.png', dpi=200)
plt.show()

# %%
plt.bar(np.arange(0, 10, 1), w[0:10])
plt.ylabel('$mL^2 E/\hbar^2$')
plt.show()
